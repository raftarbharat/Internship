# %%
# Solution for question no. 11.
num = int(input("Enter a number: "))
factorial = 1
# check if the number is negative, positive or zero
if num < 0:
    print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
    print("The factorial of 0 is 1")
else:
    for i in range(1,num + 1):
        factorial=factorial*i
    print("The factorial of",num,"is",factorial)
# Out:
# Enter a number: 2
# The factorial of 2 is 2

# %%
# Solution for question no. 12. Part 1
number=int(input("Enter the number to check prime or composite: "))#Take the number from the user.

count=0

for i in range(2,int(number/2)+1):#Loop which is used to dive the number from other number.

   if(number%i==0):

       count=1

       break

if(count==0):#For prime number.

   print("The number is prime number")

else:#For composite number.

   print("The number is composite number")
# Out:
# Enter the number to check prime or composite: 5
# The number is prime number

# %%
# Solution for question no. 12. Part 2
number=int(input("Enter the number to check prime or composite: "))#Take the number from the user.

count=0

for i in range(2,int(number/2)+1):#Loop which is used to dive the number from other number.

   if(number%i==0):

       count=1

       break

if(count==0):#For prime number.

   print("The number is prime number")

else:#For composite number.

   print("The number is composite number")
# Out:
# Enter the number to check prime or composite: 4
# The number is composite number

# %%
# Solution for question no. 13.
def isPalindrome(str):
    for i in range(0, int(len(str)/2)):
        if str[i] != str[len(str)-i-1]:
            return False
    return True
s = "malayalam"
ans = isPalindrome(s)
 
if (ans):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# Solution for question no. 14.
import math
a = float(input("Enter base: "))
b = float(input("Enter height: "))
x = float(input("Enter angle: "))

c = math.sqrt(a ** 2 + b ** 2)

print("Hypotenuse =", c)
# Out:
# Enter base: 10.5
# Enter height: 5.5
# Enter angle: 60
# Hypotenuse = 11.853269591129697

# %%
# Solution for question no. 15, part 1
import collections 
 
my_string = "Hi, this is a random string." 
 
frequencies = collections.Counter(my_string) 
 
for letter in frequencies: 
    print('{} : {}'.format(letter, frequencies[letter]))
# Out:
# H : 1
# i : 4
# , : 1
#   : 5
# t : 2
# h : 1
# s : 3
# a : 2
# r : 2
# n : 2
# d : 1
# o : 1
# m : 1
# g : 1
# . : 1

# %%
# Solution for question no. 15, part 2
str1 = input ("Enter the string: ")
d = dict()
for c in str1:
    if c in d:
        d[c] = d[c] + 1
    else:
        d[c] = 1
print(d)
# Out:
# Enter the string: Ram
# {'R': 1, 'a': 1, 'm': 1}
